# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-8301b0a2-5780-44ec-8427-89b06addeba5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8301b0a2-5780-44ec-8427-89b06addeba5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bello2.csv to bello2.csv

# %%
names=["IDcompra","usuario","edad","genero","ID","nombrearticulo","precio"]
df_csv=pd.read_csv("bello2.csv",delimiter=";",skiprows=1,names=names)

# %%
df_csv
# Out:
#      IDcompra        usuario  edad  genero     ID  \
# 0           0        Lisim78  20.0    Male  108.0
# 1           1    Lisovynya38  40.0    Male  143.0
# 2           2     Ithergue48  24.0    Male   92.0
# 3           3  Chamassasya86  24.0    Male  100.0
# 4           4      Iskosia90  23.0    Male  131.0
# ..        ...            ...   ...     ...    ...
# 775       775     Aethedru70  21.0  Female   60.0
# 776       776         Iral74  21.0    Male  164.0
# 777       777     Yathecal72  20.0    Male   67.0
# 778       778        Sisur91   7.0    Male  101.0
# 779       779      Ennrian78  24.0    Male   50.0
#
#                                 nombrearticulo  precio
# 0    Extraction, Quickblade Of Trembling Hands    3.53
# 1                            Frenzied Scimitar    1.56
# 2                                 Final Critic    4.88
# 3                                  Blindscythe    3.27
# 4                                         Fury    1.44
# ...

# %%
df_csv.iloc[5]
# Out:
# IDcompra                  5
# usuario             Yalae81
# edad                   22.0
# genero                 Male
# ID                     81.0
# nombrearticulo    Dreamkiss
# precio                 3.61
# Name: 5, dtype: object

# %%
df_csv["edad"]
# Out:
# 0      20.0
# 1      40.0
# 2      24.0
# 3      24.0
# 4      23.0
#        ...
# 775    21.0
# 776    21.0
# 777    20.0
# 778     7.0
# 779    24.0
# Name: edad, Length: 780, dtype: float64

# %%
len(df_csv)# determinar la longitud
# Out:
# 780

# %%
#contado el recuento de jugadores 
len (np.unique(df_csv["usuario"]))# se evidencia  576 usuarios distinto de los cuales lisosia93 compro 5
# Out:
# 576

# %%
recuento=pd.DataFrame(np.unique(df_csv["usuario"],return_counts=True)).T

# %%
recuento.sort_values(by=1,ascending=False)
# Out:
#                 0  1
# 360     Lisosia93  5
# 275        Iral74  4
# 246   Idastidru52  4
# 75         Asur53  3
# 274     Inguron55  3
# ..            ... ..
# 207        Hala31  1
# 206    Haisurra41  1
# 203   Hailaphos89  1
# 202  Haestyphos66  1
# 288    Iskosian40  1
#
# [576 rows x 2 columns]

# %%
df_csv[df_csv["usuario"]=="Lisosia93"] # que compro
# Out:
#      IDcompra    usuario  edad genero     ID  \
# 74         74  Lisosia93  25.0   Male   89.0
# 120       120  Lisosia93  25.0   Male   24.0
# 224       224  Lisosia93  25.0   Male  157.0
# 603       603  Lisosia93  25.0   Male  141.0
# 609       609  Lisosia93  25.0   Male   40.0
#
#                         nombrearticulo  precio
# 74   Blazefury, Protector of Delusions    4.64
# 120                      Warped Fetish    3.81
# 224            Spada, Etcher of Hatred    4.80
# 603                         Persuasion    3.19
# 609                      Second Chance    2.52

# %%
#NUNERO DE ARTICULOS UNICO
len (np.unique(df_csv["ID"]))
# Out:
# 183

# %%
#PRECIO  MEDIO DE COMPRA 
df_csv["precio"].mean()
# Out:
# 3.050987179487176

# %%
df_csv["precio"].sum()#ingreso totales
# Out:
# 2379.77

# %%
#porcentaje  y numero de jugadores masculino 
len(np.unique(df_csv[df_csv["genero"]=="Male"]["usuario"]))
# Out:
# 484

# %%
np.round(len(np.unique(df_csv[df_csv["genero"]=="Male"]["usuario"]))/576*100,2)
# Out:
# 84.03

# %%
#analisis  de recuento de compras deacuerdo al genero 

len(df_csv[df_csv["genero"]=="Female"]["precio"])
# Out:
# 113

# %%
len(df_csv[df_csv["genero"]=="Male"]["precio"])
# Out:
# 652

# %%
15+652+113
# Out:
# 780

# %%
np.unique(df_csv["genero"],return_counts=True)[1]
# Out:
# array([113, 652,  15])

# %%
plt.pie(np.unique(df_csv["genero"],return_counts=True)[1],
labels=np.unique(df_csv["genero"],return_counts=True)[0])
plt.show()

# %%
df_csv[df_csv["genero"]=="Male"]["precio"].mean()
# Out:
# 3.0178527607361953

# %%
for i in np.unique(df_csv["genero"]);
print(i,np.round(df_csv[df_csv["genero"]==i]["precio"].mean(),2))
print(i,np.round(df_csv
